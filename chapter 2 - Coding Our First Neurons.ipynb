# %% [markdown]
# A Single Neuron

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0

output = sum(inputs[i] * weights[i] for i in range(len(inputs))) + bias
print(output)
# Out:
# 4.8

# %% [markdown]
# A Layer Of Neurons (Here, 3 Neurons)

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [
    [0.2, 0.8, -0.5, 1.0],
    [0.5, -0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87]
]
biases = [2.0, 3.0, 0.5]

layer_outputs = []
for neuron_weights, neuron_bias in zip(weights, biases):
    neuron_output = 0
    for neuron_input, weight in zip(inputs, neuron_weights):
        neuron_output += neuron_input * weight
    neuron_output +=  neuron_bias
    layer_outputs.append(neuron_output)

print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# Tensors, Arrays and Vectors
# (Understand Shape)

# %%
import numpy as np

# %%
l = [1,5,6,2]
np.shape(l)
# Out:
# (4,)

# %%
lol = [[1,5,6,2], 
       [3,2,1,3]] 
np.shape(lol)
# Out:
# (2, 4)

# %%
lolol = [[[1,5,6,2], 
          [3,2,1,3]], 
         [[5,2,1,2], 
          [6,4,8,4]], 
         [[2,8,5,3], 
          [1,1,9,4]]] 
np.shape(lolol)
# Out:
# (3, 2, 4)

# %%
another_list_of_lists = [[4,2,3], 
                         [5,1]] 
np.shape(another_list_of_lists)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File e:\NN From Scratch\.venv\lib\site-packages\numpy\core\fromnumeric.py:2033, in shape(a)
#    2032 try:
# -> 2033     result = a.shape
#    2034 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 another_list_of_lists = [[4,2,3],
#       2                          [5,1]]
# ----> 3 np.shape(another_list_of_lists)
#
# File <__array_function__ internals>:200, in shape(*args, **kwargs)
#
# File e:\NN From Scratch\.venv\lib\site-packages\numpy\core\fromnumeric.py:2035, in shape(a)
#    2033     result = a.shape
#    2034 except AttributeError:
# -> 2035     result = asarray(a).shape
#    2036 return result
#
# ...

# %% [markdown]
# The above list of lists cannot be an array because it is not homologous. A list of lists is
# homologous if each list along a dimension is identically long, and this must be true for each
# dimension. In the case of the list shown above, it’s a 2-dimensional list. The first dimension’s
# length is the number of sublists in the total list (2). The second dimension is the length of each of
# those sublists (3, then 2). In the above example, when reading across the “row” dimension (also
# called the second dimension), the first list is 3 elements long, and the second list is 2 elements
# long — this is not homologous and, therefore, cannot be an array.

# %% [markdown]
# Dot Product and Vector Addition
#
# ![dot_product1.png](attachment:dot_product1.png)

# %%
a = [1,2,3] 
b = [2,3,4] 

dot_product = a[0]*b[0] + a[1]*b[1] + a[2]*b[2] 
print(dot_product)
# Out:
# 20

# %% [markdown]
# A Single Neuron with NumPy

# %%
import numpy as np 

inputs = [1.0, 2.0, 3.0, 2.5] 
weights = [0.2, 0.8, -0.5, 1.0] 
bias = 2.0 

outputs = np.dot(weights, inputs) + bias 
print(outputs)
# Out:
# 4.8

# %% [markdown]
# A Layer of Neurons with NumPy

# %%
import numpy as np 

inputs = [1.0, 2.0, 3.0, 2.5] 
weights = [
    [0.2, 0.8, -0.5, 1], 
    [0.5, -0.91, 0.26, -0.5], 
    [-0.26, -0.27, 0.17, 0.87]
] 
biases = [2.0, 3.0, 0.5] 

layer_outputs = np.dot(weights, inputs) + biases 
print(layer_outputs)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# Above code explaination:
#
# ![dot_product2.png](attachment:dot_product2.png)

# %% [markdown]
# A Batch Of Data - multiple samples at a time
#
# ![batch_of_data.png](attachment:batch_of_data.png)
#
# Above example contains 8 samples with 4 features.

# %% [markdown]
# Matrix Product
#
# ![mat1.png](attachment:mat1.png)
#
# ![mat2.png](attachment:mat2.png)
#
# ![mat3.png](attachment:mat3.png)

# %% [markdown]
# Transpose Of a Matrix
#
# ![transpose1.png](attachment:transpose1.png)

# %%
# Transpose with Numpy code

import numpy as np 

a = [1, 2, 3] 
b = [2, 3, 4] 

a = np.array([a]) 
b = np.array([b]).T 

np.dot(a, b)
# Out:
# array([[20]])

# %% [markdown]
# A Layer of Neurons & Batch of Data with NumPy

# %%
import numpy as np

inputs = [
    [1.0, 2.0, 3.0, 2.5], 
    [2.0, 5.0, -1.0, 2.0], 
    [-1.5, 2.7, 3.3, -0.8]
] 
weights = [
    [0.2, 0.8, -0.5, 1.0], 
    [0.5, -0.91, 0.26, -0.5], 
    [-0.26, -0.27, 0.17, 0.87]
] 
biases = [2.0, 3.0, 0.5] 

inputs_into_weights = np.dot(inputs, np.array(weights).T)
layer_outputs = inputs_into_weights + biases


print(f"Dot Product of inputs and transposed weights: \n{inputs_into_weights}")
print(f"\nFinal layer_output: \n{layer_outputs}")
# Out:
# Dot Product of inputs and transposed weights:
# [[ 2.8   -1.79   1.885]
#  [ 6.9   -4.81  -0.3  ]
#  [-0.59  -1.949 -0.474]]
#
# Final layer_output:
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]

# %% [markdown]
# Dot Product:
#
# ![batch_with_numpy1.png](attachment:batch_with_numpy1.png)
#
# Final Output(after adding baises):
#
# ![batch_with_numpy2.png](attachment:batch_with_numpy2.png)
